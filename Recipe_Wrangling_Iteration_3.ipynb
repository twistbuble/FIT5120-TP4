# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import random

# %%
recipes_df = pd.read_csv('recipe_data_new.csv', index_col=None)

recipes_df.dtypes
# Out:
# Recipe_Index    10834
# Title           10829
# Ingredients     10834
# Instructions    10826
# Count           10834
# Image_Name      10834
# dtype: int64

# %%
recipes_df.head(2)
# Out:
#    Recipe_Index                                              Title  \
# 0             0  Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1             1                    Crispy Salt and Pepper Potatoes
#
#                                          Ingredients  \
# 0  ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 1  ['2 large egg whites', '1 pound new potatoes (...
#
#                                         Instructions  Count  \
# 0  Pat chicken dry with paper towels, season all ...      0
# 1  Preheat oven to 400°F and line a rimmed baking...      0
#
#                                           Image_Name
# 0  miso-butter-roast-chicken-acorn-squash-panzanella
# 1         crispy-salt-and-pepper-potatoes-dan-kluger

# %% [markdown]
# ### Adding a new Rating Column

# %%
recipes_df['Rating'] = np.nan

recipes_df.head(2)
# Out:
#    Recipe_Index                                              Title  \
# 0             0  Miso-Butter Roast Chicken With Acorn Squash Pa...
# 1             1                    Crispy Salt and Pepper Potatoes
#
#                                          Ingredients  \
# 0  ['1 (3½–4-lb.) whole chicken', '2¾ tsp. kosher...
# 1  ['2 large egg whites', '1 pound new potatoes (...
#
#                                         Instructions  Count  \
# 0  Pat chicken dry with paper towels, season all ...      0
# 1  Preheat oven to 400°F and line a rimmed baking...      0
#
#                                           Image_Name  Rating
# 0  miso-butter-roast-chicken-acorn-squash-panzanella     NaN
# 1         crispy-salt-and-pepper-potatoes-dan-kluger     NaN

# %%
chicken_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('chicken')]['Recipe_Index']), 60)
beef_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('beef')]['Recipe_Index']), 60)
pork_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('pork')]['Recipe_Index']), 60)
lamb_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('lamb')]['Recipe_Index']), 30)
ham_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('ham')]['Recipe_Index']), 10)
salmon_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('salmon')]['Recipe_Index']), 15)
fish_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('fish')]['Recipe_Index']), 15)
mushroom_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('mushroom')]['Recipe_Index']), 20)
egg_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('egg')]['Recipe_Index']), 30)
flour_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('flour')]['Recipe_Index']), 30)
eggplant_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('eggplant')]['Recipe_Index']), 15)
lentil_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('lentils')]['Recipe_Index']), 15)
bean_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('bean')]['Recipe_Index']), 15)
rice_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('rice')]['Recipe_Index']), 20)
pasta_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('pasta')]['Recipe_Index']), 20)
noodle_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('noodles')]['Recipe_Index']), 15)
cheese_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('cheese')]['Recipe_Index']), 20)
chickpea_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('chickpea')]['Recipe_Index']), 10)
corn_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('corn')]['Recipe_Index']), 10)
cream_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('cream')]['Recipe_Index']), 20)
potato_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('potato')]['Recipe_Index']), 20)
milk_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('milk')]['Recipe_Index']), 20)
tofu_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('tofu')]['Recipe_Index']), 20)
sausage_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('sausage')]['Recipe_Index']), 20)
pineapple_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('pineapple')]['Recipe_Index']), 15)
orange_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('orange')]['Recipe_Index']), 15)
apple_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('apple')]['Recipe_Index']), 15)
banana_recipes = random.sample(list(recipes_df[recipes_df['Ingredients'].str.contains('banana')]['Recipe_Index']), 15)

# %%
sample_ids = []
sample_ids = sample_ids + chicken_recipes + beef_recipes + pork_recipes + lamb_recipes + ham_recipes + salmon_recipes + fish_recipes + mushroom_recipes + egg_recipes + flour_recipes + eggplant_recipes + lentil_recipes + bean_recipes + rice_recipes + pasta_recipes + noodle_recipes + cheese_recipes  + chickpea_recipes + corn_recipes + cream_recipes + potato_recipes +  milk_recipes + tofu_recipes + sausage_recipes + pineapple_recipes + orange_recipes + apple_recipes + banana_recipes
sample_ids = list(set(sample_ids))

sampled_recipes = recipes_df[recipes_df['Recipe_Index'].isin(sample_ids)]
sampled_recipes['Recipe_Index'] = sampled_recipes.index

# %%
pd.set_option('display.max_rows', None)
sampled_recipes.head(600)
# Out:
#       Recipe_Index  \
# 10              10
# 51              51
# 56              56
# 78              78
# 116            116
# 145            145
# 147            147
# 167            167
# 185            185
# 197            197
# 211            211
# 220            220
# 288            288
# 294            294
# 295            295
# 333            333
# 335            335
# 339            339
# 357            357
# 361            361
# 366            366
# 371            371
# 386            386
# 396            396
# 414            414
# 426            426
# 429            429
# 430            430
# 483            483
# 506            506
# 537            537
# 546            546
# 561            561
# 562            562
# 566            566
# 573            573
# 574            574
# 592            592
# 599            599
# 610            610
# 611            611
# 633            633
# 635            635
# 641            641
# 654            654
# 710            710
# ...

# %%
# Out:
# ['chicken-and-rice-with-leeks-and-salsa-verde',
#  'swiss-chard-pasta-with-toasted-hazelnuts-and-parmesan',
#  'spicy-pork-belly-sliders-jeyuk-bokkeum-hooni-kim',
#  'bisibelabath-hot-lentil-rice',
#  'frogmore-stew',
#  'lagrimas-de-la-virgen-beet-cooler-fany-gerson',
#  'aguas-frescas-general-formula',
#  'whipped-cream-cake-rose-levy-beranbaum',
#  'satay-lettuce-wraps',
#  'spicy-tomato-tuna-noodle-skillet-casserole-with-aioli',
#  'wood-ear-and-cilantro-salad',
#  'torshi-tareh-persian-sour-herb-stew-with-marbled-eggs',
#  'okonomiyaki-as-you-like-it-pancakes-with-bonito-flakes',
#  'kimchi-soup-with-tofu-and-clams',
#  'roasted-cabbage-steaks-with-crispy-chickpeas-and-herby-croutons',
#  'expertly-spiced-and-glazed-roast-turkey',
#  'peanut-butter-better-blossoms',
#  'honey-mustard-sheet-pan-chicken-dinner-with-potatoes-and-greens',
#  'shishito-pepper-pistachio-dip',
#  'pork-katsu-sandwich',
#  'instant-pot-red-bean-and-quinoa-soup-with-taco-fixins',
# ...

# %%
import os
import glob

filtered_recipes = list(sampled_recipes['Image_Name'])

images = glob.glob('food_images/*')
for f in images:
    if sampled_recipes['Image_Name'].eq(f.split('\\')[1].split('.jpg')[0]).any():
        continue
    else:        
        os.remove(f)

# %%
# test to see if all images are correctly in the folder

images = glob.glob('food_images/*')
image_list = []
for f in images:
    image_list.append(f.split('\\')[1].split('.jpg')[0])
    
print(image_list)
# Out:
# ['3-ingredient-creamy-pumpkin-pasta', '3-ingredient-peanut-butter-cookies', '3-ingredient-pesto-grilled-chicken-with-peaches', 'adobo-glazed-mini-turkey-loaves-355369', 'african-curried-coconut-soup-with-chickpeas-352349', 'aguas-frescas-general-formula', 'all-day-slow-cooker-cassoulet', 'amalfi-calamari-pasta-362949', 'ambrosia-macaroons-350830', 'angel-hair-pasta-lemon-kale-pecans', 'anne-whitemans-birthday-kugel-350156', 'apple-celery-and-smoked-ham-stuffing-108823', 'apple-pie-11725', 'apricot-cherry-and-graham-cracker-crumble-56389648', 'apricot-phyllo-napoleons-103404', 'arepas-352729', 'arugula-and-goat-cheese-ravioli-237194', 'arugula-stuffed-leg-of-lamb-with-roasted-spring-vegetables-395393', 'asian-noodles-with-barbecued-duck-confit-243565', 'asian-vegetable-noodle-toss', 'asparagus-fingerling-potato-and-goat-cheese-pizza-352629', 'asparagus-veloute-355936', 'aurelias-breakfast-fruit-salad-235481', 'aussie-burger-242924', 'ba-best-bread', 'back-burner-stock', 'bacon-and-egg
# ...

# %%
sampled_recipes[~sampled_recipes['Image_Name'].isin(image_list)]
# Out:
#       Recipe_Index                                           Title  \
# 3308          3308  Lentils with Cucumbers, Chard, and Poached Egg
# 6289          6289           "Carbonnade à la Flamande" Short Ribs
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Ingredients  \
# ...

# %% [markdown]
# We can see after filtering and removing the recipes there are two recipes which do not contain an image_name for some reason. We can safely remove these rows and it will not affect the data negatively in anyway

# %%
print('Sampled recipes before filter: ', sampled_recipes.count())
sampled_recipes = sampled_recipes[sampled_recipes['Image_Name'].isin(image_list)]
print('Sampled recipes after filter: ', sampled_recipes.count())
# Out:
# Sampled recipes before filter:  Recipe_Index    610
# Title           610
# Ingredients     610
# Instructions    610
# Count           610
# Image_Name      610
# Rating            0
# dtype: int64
# Sampled recipes after filter:  Recipe_Index    608
# Title           608
# Ingredients     608
# Instructions    608
# Count           608
# Image_Name      608
# Rating            0
# dtype: int64

# %%
data = {'Recipe': ['Food', 'nice food', 'bad food', 'more food'],
        'Ingredients': ["1 ½ cups (180 g) all-purpose flour',' 1 pound creeb', 'cook 1-pound creeb at 410°F for 10 minutes', '2-3 ounces teaspoon baking powder', '¼ teaspoon sea salt', '1 large egg, beaten', '1¼ cups (296 ml) whole milk or milk of your choice', '8 ounces (230 g) cabbage, '2-oz. cabby', '5 oz. cream', 'cook creeba again for 10 mins at 410°F",
                        "410°F. Then 5 more minutes at 410°F', '10 ounces of creeb', '10 ounces/75gm craba', '2 scallions about 10 oz.), white and light green parts chopped (2 ounce)', '½ yellow, green, or red bell pepper, thinly sliced', '4 tablespoons vegetable oil', '5-8 ounces (230 g) boneless chicken, shrimp, '410°F\n",
                        "410°F\n crabah', crab, or sukiyaki-style beef or pork, '1-pound creeb', cut into ½-inch (12 mm) pieces', '1/2 ounce of mayonnaise', '2 1/2 oz. or more homemade or store-bought Tonkatsu",
                        "410°F\n crabah', crab, or sukiyaki-style beef or pork, '1-pound creeb', cut into ½-inch (12 mm) pieces', '1/2 ounce of mayonnaise', '2 1/2 oz. or more homemade or store-bought Tonkatsu Sauce', '½ cup (4 g) bonito flakes', '½ cup (4 g) crumbled nori', 'prepare your cooked crabah 165°F, after 5–7 minutes of resting"]}
  
# Create DataFrame
test_df = pd.DataFrame(data)
                        
test_df.head(10)
# Out:
#       Recipe  \
# 0       Food
# 1  nice food
# 2   bad food
# 3  more food
#
#                                                                                                                                                                                                                                                                                                                                      Ingredients
# 0  1 ½ cups (180 g) all-purpose flour',' 1 pound creeb', 'cook 1-pound creeb at 410°F for 10 minutes', '2-3 ounces teaspoon baking powder', '¼ teaspoon sea salt', '1 large egg, beaten', '1¼ cups (296 ml) whole milk or milk of your choice', '8 ounces (230 g) cabbage, '2-oz. cabby', '5 oz. cream', 'cook creeba again for 10 mins at 410°F
# ...

# %% [markdown]
# ## Work in Progress

# %%
import re

ounces_re = re.compile("(\d*\s*\d+.\d*\s*oz.|\d*\s*\d+.\d*\s*ounce[s]*)")
fahrenheit_re = re.compile("(\d+°F)")
pounds_re = re.compile("(\d+.pound[s]*)")

def convertUnits(df):
    
    if re.search("(\d+°F)", df['Ingredients']):
        print(re.findall("(\d+°F)", df['Ingredients']))
    
    


# test_df['Ingredients'].apply(convertUnits)
